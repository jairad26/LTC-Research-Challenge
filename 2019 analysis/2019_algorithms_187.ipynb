# %%
# %pip install statsmodels
# %pip install patsy

# %%
import pandas as pd 
import math
import matplotlib.pyplot as plt
import numpy as np
import datetime
from scipy.stats import chi2_contingency
import pandas as pd
import numpy as np
from sklearn import preprocessing, neighbors, svm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error
import pickle
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as stats
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor # Import Decision Tree Classifier
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
from sklearn.ensemble import RandomForestRegressor


df = pd.read_csv('data/2019 Line 187 allscripts.csv')
df.head()
df['Actual Depart Hour'] = df['Actual Depart'].str.split(':',expand=True)[0]
df['Actual Depart Hour'] = df['Actual Depart Hour'].astype(int)
df['Transit Date Month'] = df['Transit Date'].str.split('/',expand=True)[0]
df['Transit Date Month'] = df['Transit Date Month'].astype(int)

# %%
df1 = df.copy()
# df1 = df.loc[(df['Bus Stop ID'] == 775) | (df['Bus Stop ID'] == 782) | (df['Bus Stop ID'] == 733)]
#df1 = df.loc[(df['Bus Stop ID'] != 177)]
#df1 = df1.loc[(df1['Bus Stop ID'] != 738)]
#df1 = df1.loc[(df1['Bus Stop ID'] != 2199)]
#df1 = df1.loc[(df1['Bus Stop ID'] != 2384)]

df1 = pd.get_dummies(df1, columns=['Actual Depart Hour', 'Transit Date Month', 'Day of Week', \
    'Miles from Prior Time Point', 'Bus Stop ID'],prefix=['Enc_Hour_', 'Enc_Month_', 'Enc_Day_',\
        'Enc_Miles_', 'Enc_Stop_'])
# df1 = pd.get_dummies(df1, columns=['Actual Depart Hour', 'Transit Date Month', 'Day of Week', \
#     'Miles from Prior Time Point'],prefix=['Enc_Hour_', 'Enc_Month_', 'Enc_Day_',\
#         'Enc_Miles_'])
# df1 = pd.get_dummies(df1, columns=['Transit Date Month'],prefix=['Enc_Month_'])

# df1['Transit Date Month'] = df1['Transit Date'].str.split('/',expand=True)[0]
df1.fillna(value = -9999)
enc = OneHotEncoder(handle_unknown='ignore')

df1['Difference (Minutes)'] = df1['Difference (Minutes)'].astype(int)
df1['Prev Departure Offset'] = df1['Prev Departure Offset'].astype(int)
df1.head()
# df.replace('?', -99999, inplace=True) #sees -99999 as outlier, ignores it
df1.drop(['Transit Date', 'Badge #', 'Block #', 'Stop Sequence', 'Latitude', 'Longitude', 'Actual Arrival', 'Dwell Time', \
    'Scheduled Run Time', 'Actual Run Time', 'Actual Depart', 'Prev Departure Offset'], 1, inplace=True)
# print(df1.head)
# pd.to_numeric(df1['Actual Operating Speed'], errors='coerce')
df2 = df1.drop(['Difference (Minutes)'],1)
X = np.array(df2) #using everything except class to train
Y = np.array(df1['Difference (Minutes)']) #class is the final result obviously
np.nan_to_num(X)
np.nan_to_num(Y)
pd.isnull(X)
np.nan_to_num(X)

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3)

# clf = SGDRegressor(loss='huber', penalty='l1')
# clf = SGDRegressor(penalty='elasticnet')
clf = DecisionTreeClassifier(criterion="entropy", splitter="random")
# clf = DecisionTreeRegressor()
# clf = RandomForestRegressor(n_estimators = 50)


# %time clf.fit(X_train, Y_train)

filename = 'models/2019_clf_model_9_15.sav'
pickle.dump(clf, open(filename, 'wb'))

plt.scatter(Y_test, clf.predict(X_test))
plt.grid()
plt.xlabel('Actual y')
plt.ylabel('Predicted y')
plt.title('scatter plot between actual y and predicted y')
plt.show()
print('Root Mean Squared Error :',math.sqrt(mean_squared_error(Y_test, clf.predict(X_test))))
print('Mean Absolute Error :',mean_absolute_error(Y_test, clf.predict(X_test)))

scores = cross_val_score(clf, X_test, Y_test, cv=5)

print(scores)
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))

# fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10,4), sharey=True)
# ax.plot(X_train, clf.fit(X_train, Y_train).predict(X_train), lw=2)
# ax.scatter(X_train[clf.support_], Y_train[clf.support_], facecolor="none",s=50)
# # ax.scatter(X_test[np.setdiff1d(np.arange(len(X_test)),clf.support_)],
# #            Y_test[np.setdiff1d(np.arange(len(X_test)), clf.support_)],
# #            facecolor="none", edgecolor="k", s=50)


# fig.text(0.5, 0.04, 'data', ha='center', va='center')
# fig.text(0.06, 0.5, 'target', ha='center', va='center', rotation='vertical')
# fig.suptitle("Support Vector Regression", fontsize=14)
# plt.show()
# Out:
# /var/folders/sl/46hc8zqn0l9_kwvskdqj7z8h0000gn/T/ipykernel_94979/381524693.py:24: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df1.drop(['Transit Date', 'Badge #', 'Block #', 'Stop Sequence', 'Latitude', 'Longitude', 'Actual Arrival', 'Dwell Time', \
# /var/folders/sl/46hc8zqn0l9_kwvskdqj7z8h0000gn/T/ipykernel_94979/381524693.py:28: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df2 = df1.drop(['Difference (Minutes)'],1)
# CPU times: user 1.07 s, sys: 16.4 ms, total: 1.09 s
# Wall time: 1.09 s
# Root Mean Squared Error : 6.626426724541358
# Mean Absolute Error : 3.4887386819339707
# /Users/jairadhakrishnan/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py:666: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# [0.32875158 0.32496847 0.32421185 0.32118537 0.32097364]
# 0.32 accuracy with a standard deviation of 0.00

# %%
importances = list(clf.feature_importances_)
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(df2.columns, importances)]
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances]
# Out:
# Variable: Enc_Stop__2240       Importance: 0.07
# Variable: Enc_Day__Friday      Importance: 0.04
# Variable: Enc_Stop__177        Importance: 0.04
# Variable: Enc_Hour__17         Importance: 0.03
# Variable: Enc_Hour__19         Importance: 0.03
# Variable: Enc_Month__10        Importance: 0.03
# Variable: Enc_Day__Saturday    Importance: 0.03
# Variable: Enc_Day__Thursday    Importance: 0.03
# Variable: Enc_Hour__15         Importance: 0.02
# Variable: Enc_Hour__16         Importance: 0.02
# Variable: Enc_Hour__18         Importance: 0.02
# Variable: Enc_Hour__20         Importance: 0.02
# Variable: Enc_Month__8         Importance: 0.02
# Variable: Enc_Month__12        Importance: 0.02
# Variable: Enc_Day__Monday      Importance: 0.02
# Variable: Enc_Day__Sunday      Importance: 0.02
# Variable: Enc_Day__Tuesday     Importance: 0.02
# Variable: Enc_Day__Wednesday   Importance: 0.02
# Variable: Enc_Stop__1068       Importance: 0.02
# Variable: Enc_Stop__1069       Importance: 0.02
# Variable: Enc_Stop__1777       Importance: 0.02
# Variable: Enc_Stop__1812       Importance: 0.02
# Variable: Enc_Hour__4          Importance: 0.01
# Variable: Enc_Hour__5          Importance: 0.01
# Variable: Enc_Hour__6          Importance: 0.01
# Variable: Enc_Hour__7          Importance: 0.01
# Variable: Enc_Hour__8          Importance: 0.01
# Variable: Enc_Hour__9          Importance: 0.01
# Variable: Enc_Hour__10         Importance: 0.01
# Variable: Enc_Hour__11         Importance: 0.01
# Variable: Enc_Hour__12         Importance: 0.01
# Variable: Enc_Hour__13         Importance: 0.01
# Variable: Enc_Hour__14         Importance: 0.01
# Variable: Enc_Hour__21         Importance: 0.01
# Variable: Enc_Hour__22         Importance: 0.01
# Variable: Enc_Hour__23         Importance: 0.01
# Variable: Enc_Month__2         Importance: 0.01
# Variable: Enc_Month__3         Importance: 0.01
# Variable: Enc_Month__4         Importance: 0.01
# Variable: Enc_Month__5         Importance: 0.01
# Variable: Enc_Month__6         Importance: 0.01
# Variable: Enc_Month__7         Importance: 0.01
# Variable: Enc_Month__9         Importance: 0.01
# Variable: Enc_Miles__0.0       Importance: 0.01
# Variable: Enc_Miles__11.201    Importance: 0.01
# Variable: Enc_Miles__12.189    Importance: 0.01
# Variable: Enc_Miles__12.19     Importance: 0.01
# Variable: Enc_Miles__24.366    Importance: 0.01
# Variable: Enc_Miles__24.493    Importance: 0.01
# Variable: Enc_Miles__26.28     Importance: 0.01
# Variable: Enc_Stop__1780       Importance: 0.01
# Variable: Enc_Stop__1813       Importance: 0.01
# Variable: Enc_Hour__0          Importance: 0.0
# Variable: Enc_Month__1         Importance: 0.0
# Variable: Enc_Miles__-0.579    Importance: 0.0
# Variable: Enc_Miles__0.579     Importance: 0.0
# Variable: Enc_Miles__0.589     Importance: 0.0
# Variable: Enc_Miles__0.628     Importance: 0.0
# Variable: Enc_Miles__0.771     Importance: 0.0
# Variable: Enc_Miles__0.96      Importance: 0.0
# Variable: Enc_Miles__1.069     Importance: 0.0
# Variable: Enc_Miles__1.298     Importance: 0.0
# Variable: Enc_Miles__1.318     Importance: 0.0
# Variable: Enc_Miles__3.662     Importance: 0.0
# Variable: Enc_Miles__3.993     Importance: 0.0
# Variable: Enc_Miles__4.151     Importance: 0.0
# Variable: Enc_Miles__4.481     Importance: 0.0
# Variable: Enc_Miles__4.495     Importance: 0.0
# Variable: Enc_Miles__4.859     Importance: 0.0
# Variable: Enc_Miles__5.082     Importance: 0.0
# Variable: Enc_Miles__5.134     Importance: 0.0
# Variable: Enc_Miles__5.203     Importance: 0.0
# Variable: Enc_Miles__5.691     Importance: 0.0
# Variable: Enc_Miles__5.735     Importance: 0.0
# Variable: Enc_Miles__6.554     Importance: 0.0
# Variable: Enc_Miles__11.09     Importance: 0.0
# Variable: Enc_Miles__11.624    Importance: 0.0
# Variable: Enc_Miles__11.628    Importance: 0.0
# Variable: Enc_Miles__11.713    Importance: 0.0
# Variable: Enc_Miles__11.844    Importance: 0.0
# Variable: Enc_Miles__11.879    Importance: 0.0
# Variable: Enc_Miles__11.896    Importance: 0.0
# Variable: Enc_Miles__11.958    Importance: 0.0
# Variable: Enc_Miles__11.962    Importance: 0.0
# Variable: Enc_Miles__11.982    Importance: 0.0
# Variable: Enc_Miles__11.991    Importance: 0.0
# Variable: Enc_Miles__12.107    Importance: 0.0
# Variable: Enc_Miles__12.117    Importance: 0.0
# Variable: Enc_Miles__12.181    Importance: 0.0
# Variable: Enc_Miles__12.224    Importance: 0.0
# Variable: Enc_Miles__12.378    Importance: 0.0
# Variable: Enc_Miles__12.56     Importance: 0.0
# Variable: Enc_Miles__12.596    Importance: 0.0
# Variable: Enc_Miles__12.652    Importance: 0.0
# Variable: Enc_Miles__12.665    Importance: 0.0
# Variable: Enc_Miles__12.666    Importance: 0.0
# Variable: Enc_Miles__12.741    Importance: 0.0
# Variable: Enc_Miles__12.787    Importance: 0.0
# Variable: Enc_Miles__12.81     Importance: 0.0
# Variable: Enc_Miles__12.816    Importance: 0.0
# Variable: Enc_Miles__12.834    Importance: 0.0
# Variable: Enc_Miles__12.867    Importance: 0.0
# Variable: Enc_Miles__12.872    Importance: 0.0
# Variable: Enc_Miles__12.888    Importance: 0.0
# Variable: Enc_Miles__12.907    Importance: 0.0
# Variable: Enc_Miles__13.004    Importance: 0.0
# Variable: Enc_Miles__13.01     Importance: 0.0
# Variable: Enc_Miles__13.026    Importance: 0.0
# Variable: Enc_Miles__13.053    Importance: 0.0
# Variable: Enc_Miles__13.103    Importance: 0.0
# Variable: Enc_Miles__13.127    Importance: 0.0
# Variable: Enc_Miles__13.14     Importance: 0.0
# Variable: Enc_Miles__13.218    Importance: 0.0
# Variable: Enc_Miles__13.262    Importance: 0.0
# Variable: Enc_Miles__13.281    Importance: 0.0
# Variable: Enc_Miles__13.419    Importance: 0.0
# Variable: Enc_Miles__13.55     Importance: 0.0
# Variable: Enc_Miles__13.917    Importance: 0.0
# Variable: Enc_Miles__13.925    Importance: 0.0
# Variable: Enc_Miles__14.984    Importance: 0.0
# Variable: Enc_Miles__15.452    Importance: 0.0
# Variable: Enc_Miles__15.767    Importance: 0.0
# Variable: Enc_Miles__16.306    Importance: 0.0
# Variable: Enc_Miles__16.368    Importance: 0.0
# Variable: Enc_Miles__16.42     Importance: 0.0
# Variable: Enc_Miles__20.41     Importance: 0.0
# Variable: Enc_Miles__20.613    Importance: 0.0
# Variable: Enc_Miles__22.617    Importance: 0.0
# Variable: Enc_Miles__23.751    Importance: 0.0
# Variable: Enc_Miles__24.906    Importance: 0.0
# Variable: Enc_Miles__25.065    Importance: 0.0
# Variable: Enc_Miles__25.106    Importance: 0.0
# Variable: Enc_Miles__25.14     Importance: 0.0
# Variable: Enc_Miles__25.152    Importance: 0.0
# Variable: Enc_Miles__25.172    Importance: 0.0
# Variable: Enc_Miles__25.184    Importance: 0.0
# Variable: Enc_Miles__25.387    Importance: 0.0
# Variable: Enc_Miles__25.409    Importance: 0.0
# Variable: Enc_Miles__25.425    Importance: 0.0
# Variable: Enc_Miles__25.429    Importance: 0.0
# Variable: Enc_Miles__25.441    Importance: 0.0
# Variable: Enc_Miles__25.529    Importance: 0.0
# Variable: Enc_Miles__25.6      Importance: 0.0
# Variable: Enc_Miles__25.72     Importance: 0.0
# Variable: Enc_Miles__25.803    Importance: 0.0
# Variable: Enc_Miles__25.881    Importance: 0.0
# Variable: Enc_Miles__26.024    Importance: 0.0
# Variable: Enc_Miles__26.052    Importance: 0.0
# Variable: Enc_Miles__26.087    Importance: 0.0
# Variable: Enc_Miles__26.095    Importance: 0.0
# Variable: Enc_Miles__26.235    Importance: 0.0
# Variable: Enc_Miles__26.323    Importance: 0.0
# Variable: Enc_Miles__26.48     Importance: 0.0
# Variable: Enc_Miles__26.557    Importance: 0.0
# Variable: Enc_Miles__26.622    Importance: 0.0
# Variable: Enc_Miles__26.654    Importance: 0.0
# Variable: Enc_Miles__26.738    Importance: 0.0
# Variable: Enc_Miles__26.822    Importance: 0.0
# Variable: Enc_Miles__26.933    Importance: 0.0
# Variable: Enc_Miles__26.979    Importance: 0.0
# Variable: Enc_Miles__27.02     Importance: 0.0
# Variable: Enc_Miles__27.086    Importance: 0.0
# Variable: Enc_Miles__27.179    Importance: 0.0
# Variable: Enc_Miles__27.235    Importance: 0.0
# Variable: Enc_Miles__27.319    Importance: 0.0
# Variable: Enc_Miles__27.375    Importance: 0.0
# Variable: Enc_Miles__27.526    Importance: 0.0
# Variable: Enc_Miles__27.553    Importance: 0.0
# Variable: Enc_Miles__27.717    Importance: 0.0
# Variable: Enc_Miles__27.795    Importance: 0.0
# Variable: Enc_Miles__27.954    Importance: 0.0
# Variable: Enc_Miles__27.971    Importance: 0.0
# Variable: Enc_Miles__28.001    Importance: 0.0
# Variable: Enc_Miles__28.009    Importance: 0.0
# Variable: Enc_Miles__28.098    Importance: 0.0
# Variable: Enc_Miles__28.566    Importance: 0.0
# Variable: Enc_Miles__28.568    Importance: 0.0
# Variable: Enc_Miles__28.868    Importance: 0.0
# Variable: Enc_Miles__29.274    Importance: 0.0
# Variable: Enc_Miles__29.922    Importance: 0.0
# Variable: Enc_Miles__30.822    Importance: 0.0
# Variable: Enc_Miles__44.465    Importance: 0.0
# Variable: Enc_Miles__48.143    Importance: 0.0
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# from sklearn.tree import export_graphviz
# import pydot
# # Pull out one tree from the forest
# tree = clf.estimators_[5]
# # Export the image to a dot file
# export_graphviz(tree, out_file = 'tree.dot', feature_names = df2.columns, rounded = True, precision = 1)
# # Use dot file to create a graph
# (graph, ) = pydot.graph_from_dot_file('tree.dot')
# # Write graph to a png file
# graph.write_png('tree.png')
