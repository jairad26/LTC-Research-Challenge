# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import datetime

# %%
df = pd.read_csv('data/2020 Line 280 AVL report.csv')
df['Run Time Variance'][df['Run Time Variance'] < 0] = 0
df['Actual Run Time'][df['Actual Run Time'].astype(int) < 0] = 0
df['Scheduled Run Time'][df['Scheduled Run Time'].astype(int) < 0] = 0
df.head()
# Out:
# C:\Users\Jai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (19,20,24) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <ipython-input-154-66c5543a1431>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Run Time Variance'][df['Run Time Variance'] < 0] = 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-154-66c5543a1431> in <module>
#       1 df = pd.read_csv('data/2020 Line 280 AVL report.csv')
#       2 df['Run Time Variance'][df['Run Time Variance'] < 0] = 0
# ----> 3 df['Actual Run Time'][int(df['Actual Run Time']) < 0] = 0
#       4 df['Scheduled Run Time'][int(df['Scheduled Run Time']) < 0] = 0
#       5 df.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#     139         if len(self) == 1:
#     140             return converter(self.iloc[0])
# --> 141         raise TypeError(f"cannot convert the series to {converter}")
#     142
#     143     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'int'>

# %%
# bus_actual_runtime=df.groupby(['Transit Date'])['Actual Run Time'].sum().reset_index()

bus_variance_runtime=df.groupby(['Transit Date'])['Run Time Variance'].sum().reset_index()
# Out:
# 420735

# %%
customdate = datetime.datetime(2020, 1, 1, 0, 00)
x = [customdate + datetime.timedelta(days=i) for i in range(len(bus_expected_runtime))]
plt.plot(x, bus_expected_runtime['Run Time Variance'])
  
# naming the x axis
plt.xlabel('x - axis')
# naming the y axis
plt.ylabel('y - axis')
  
# giving a title to my graph
plt.title('My first graph!')
  
# function to show the plot
plt.show()
