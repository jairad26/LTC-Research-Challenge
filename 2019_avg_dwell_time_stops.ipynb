# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import datetime
df = pd.read_csv('data/2019 Line 280 AVL.csv')
df['Actual Depart Hour'] = df['Actual Depart'].str.split(':',expand=True)[0]

bus_dwell_time = df.groupby(['Bus Stop ID','Actual Depart Hour'])['Dwell Time'].mean().reset_index()

# %%
stopactual = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 177]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")
# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])


plt.plot(stopactual['Actual Depart Hour'], stopactual['Dwell Time'], label = 'Dwell Time')
  


# # giving a title to my graph
plt.title('Average 2019 Bus Dwell Time at Stop 177 Throughout Day')
plt.legend()
plt.grid()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-15-9eb405e4910f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)

# %%
stopactual = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 733]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")
# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])


plt.plot(stopactual['Actual Depart Hour'], stopactual['Dwell Time'], label = 'Dwell Time')
  

plt.grid()

# # giving a title to my graph
plt.title('Average 2019 Bus Dwell Time at Stop 733 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-16-d6a07f9b69df>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)

# %%
stopactual = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 738]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")  
# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])


plt.plot(stopactual['Actual Depart Hour'], stopactual['Dwell Time'], label = 'Dwell Time')
  

plt.grid()

# # giving a title to my graph
plt.title('Average 2019 Bus Dwell Time at Stop 738 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-17-e3cfc1988677>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)

# %%
stopactual = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 739]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")  
# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])


plt.plot(stopactual['Actual Depart Hour'], stopactual['Dwell Time'], label = 'Dwell Time')
  
plt.grid()


# # giving a title to my graph
plt.title('Average 2019 Bus Dwell Time at Stop 739 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-18-a2f36d806548>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)

# %%
stopactual = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 741]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")  
# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')

plt.grid()

# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Dwell Time'], label = 'Dwell Time')
  


# # giving a title to my graph
plt.title('Average 2019 Bus Dwell Time at Stop 741 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-19-6eac02393aa7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)

# %%
stopactual = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 744]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")  
# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')

plt.grid()

# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Dwell Time'], label = 'Dwell Time')
  


# # giving a title to my graph
plt.title('Average 2019 Bus Dwell Time at Stop 744 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-20-48880b7466d8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)

# %%
stopactual = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 745]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")  
# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

plt.grid()

plt.plot(stopactual['Actual Depart Hour'], stopactual['Dwell Time'], label = 'Dwell Time')
  


# # giving a title to my graph
plt.title('Average 2019 Bus Dwell Time at Stop 745 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-21-0aa62b60d63b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)

# %%
stopactual = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 775]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")  
# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])
plt.grid()

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Dwell Time'], label = 'Dwell Time')
  


# # giving a title to my graph
plt.title('Average 2019 Bus Dwell Time at Stop 775 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-22-8eba661930a9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)

# %%
stopactual = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 782]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")  
# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Dwell Time'], label = 'Dwell Time')
  


# # giving a title to my graph
plt.title('Average 2019 Bus Dwell Time at Stop 782 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-23-2730e84f206d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)

# %%
stopactual = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 783]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")  
# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])
plt.grid()

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Dwell Time'], label = 'Dwell Time')
  


# # giving a title to my graph
plt.title('Average 2019 Bus Dwell Time at Stop 783 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-24-ea42ab680856>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)

# %%
stopactual = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 2199]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")  
# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')
plt.grid()


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Dwell Time'], label = 'Dwell Time')
  


# # giving a title to my graph
plt.title('Average 2019 Bus Dwell Time at Stop 2199 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-25-3a741ac20f09>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)

# %%
stopactual = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 2384]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")  
# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')
plt.grid()


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Dwell Time'], label = 'Dwell Time')
  


# # giving a title to my graph
plt.title('Average 2019 Bus Dwell Time at Stop 2384 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-26-ce6ab980f010>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
