# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import datetime
# df = pd.read_csv('data/2020 Line 280 AVL report.csv')
df = pd.read_csv('data/2019 Line 280 AVL.csv')
df['Actual Depart Hour'] = df['Actual Depart'].str.split(':',expand=True)[0]
df['Scheduled Depart Hour'] = df['Scheduled Depart'].str.split(':',expand=True)[0]

bus_actual_runtime = df.groupby(['Bus Stop ID','Actual Depart Hour'])['Actual Run Time'].sum().reset_index()
bus_expected_runtime = df.groupby(['Bus Stop ID','Scheduled Depart Hour'])['Scheduled Run Time'].sum().reset_index()

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 177]
stopexpected = bus_expected_runtime.loc[bus_expected_runtime['Bus Stop ID'] == 177]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)


stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(int)
stopexpected = stopexpected.sort_values(by=['Scheduled Depart Hour'])
stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(str)


# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Actual Run Time')
plt.plot(stopexpected['Scheduled Depart Hour'], stopexpected['Scheduled Run Time'], label = 'Scheduled Run Time')
  


# # giving a title to my graph
plt.title('2019 Bus Run Time at Stop 177 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-2-a9eb0888a837>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-2-a9eb0888a837>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(int)

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 733]
stopexpected = bus_expected_runtime.loc[bus_expected_runtime['Bus Stop ID'] == 733]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)


stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(int)
stopexpected = stopexpected.sort_values(by=['Scheduled Depart Hour'])
stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(str)


# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Actual Run Time')
plt.plot(stopexpected['Scheduled Depart Hour'], stopexpected['Scheduled Run Time'], label = 'Scheduled Run Time')
  


# # giving a title to my graph
plt.title('2019 Bus Run Time at Stop 733 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-3-7d7104409290>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-3-7d7104409290>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(int)

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 738]
stopexpected = bus_expected_runtime.loc[bus_expected_runtime['Bus Stop ID'] == 738]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)


stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(int)
stopexpected = stopexpected.sort_values(by=['Scheduled Depart Hour'])
stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(str)


# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Actual Run Time')
plt.plot(stopexpected['Scheduled Depart Hour'], stopexpected['Scheduled Run Time'], label = 'Scheduled Run Time')
  


# # giving a title to my graph
plt.title('2019 Bus Run Time at Stop 738 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-4-4c4198dc07e5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-4-4c4198dc07e5>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(int)

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 739]
stopexpected = bus_expected_runtime.loc[bus_expected_runtime['Bus Stop ID'] == 739]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)


stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(int)
stopexpected = stopexpected.sort_values(by=['Scheduled Depart Hour'])
stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(str)


# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Actual Run Time')
plt.plot(stopexpected['Scheduled Depart Hour'], stopexpected['Scheduled Run Time'], label = 'Scheduled Run Time')
  


# # giving a title to my graph
plt.title('2019 Bus Run Time at Stop 739 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-5-e3564e405f73>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-5-e3564e405f73>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(int)

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 741]
stopexpected = bus_expected_runtime.loc[bus_expected_runtime['Bus Stop ID'] == 741]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)


stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(int)
stopexpected = stopexpected.sort_values(by=['Scheduled Depart Hour'])
stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(str)


# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Actual Run Time')
plt.plot(stopexpected['Scheduled Depart Hour'], stopexpected['Scheduled Run Time'], label = 'Scheduled Run Time')
  


# # giving a title to my graph
plt.title('2019 Bus Run Time at Stop 741 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-6-40ac88709474>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-6-40ac88709474>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(int)

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 744]
stopexpected = bus_expected_runtime.loc[bus_expected_runtime['Bus Stop ID'] == 744]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)


stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(int)
stopexpected = stopexpected.sort_values(by=['Scheduled Depart Hour'])
stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(str)


# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Actual Run Time')
plt.plot(stopexpected['Scheduled Depart Hour'], stopexpected['Scheduled Run Time'], label = 'Scheduled Run Time')
  


# # giving a title to my graph
plt.title('2019 Bus Run Time at Stop 744 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-7-8216cdf7cc4a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-7-8216cdf7cc4a>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(int)

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 745]
stopexpected = bus_expected_runtime.loc[bus_expected_runtime['Bus Stop ID'] == 745]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)


stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(int)
stopexpected = stopexpected.sort_values(by=['Scheduled Depart Hour'])
stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(str)


# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Actual Run Time')
plt.plot(stopexpected['Scheduled Depart Hour'], stopexpected['Scheduled Run Time'], label = 'Scheduled Run Time')
  


# # giving a title to my graph
plt.title('2019 Bus Run Time at Stop 745 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-8-4fd9103013bd>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-8-4fd9103013bd>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(int)

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 775]
stopexpected = bus_expected_runtime.loc[bus_expected_runtime['Bus Stop ID'] == 775]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)


stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(int)
stopexpected = stopexpected.sort_values(by=['Scheduled Depart Hour'])
stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(str)


# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Actual Run Time')
plt.plot(stopexpected['Scheduled Depart Hour'], stopexpected['Scheduled Run Time'], label = 'Scheduled Run Time')
  


# # giving a title to my graph
plt.title('2019 Bus Run Time at Stop 775 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-9-0a34dd77f0bb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-9-0a34dd77f0bb>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(int)

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 782]
stopexpected = bus_expected_runtime.loc[bus_expected_runtime['Bus Stop ID'] == 782]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)


stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(int)
stopexpected = stopexpected.sort_values(by=['Scheduled Depart Hour'])
stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(str)


# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Actual Run Time')
plt.plot(stopexpected['Scheduled Depart Hour'], stopexpected['Scheduled Run Time'], label = 'Scheduled Run Time')
  


# # giving a title to my graph
plt.title('2019 Bus Run Time at Stop 782 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-10-11fc122b2bf8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-10-11fc122b2bf8>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(int)

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 783]
stopexpected = bus_expected_runtime.loc[bus_expected_runtime['Bus Stop ID'] == 783]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)


stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(int)
stopexpected = stopexpected.sort_values(by=['Scheduled Depart Hour'])
stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(str)


# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Actual Run Time')
plt.plot(stopexpected['Scheduled Depart Hour'], stopexpected['Scheduled Run Time'], label = 'Scheduled Run Time')
  


# # giving a title to my graph
plt.title('2019 Bus Run Time at Stop 783 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-11-f41218b3f218>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-11-f41218b3f218>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(int)

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 2199]
stopexpected = bus_expected_runtime.loc[bus_expected_runtime['Bus Stop ID'] == 2199]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)


stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(int)
stopexpected = stopexpected.sort_values(by=['Scheduled Depart Hour'])
stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(str)


# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Actual Run Time')
plt.plot(stopexpected['Scheduled Depart Hour'], stopexpected['Scheduled Run Time'], label = 'Scheduled Run Time')
  


# # giving a title to my graph
plt.title('2019 Bus Run Time at Stop 2199 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-12-d96721bd9ce2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-12-d96721bd9ce2>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(int)

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 2384]
stopexpected = bus_expected_runtime.loc[bus_expected_runtime['Bus Stop ID'] == 2384]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)


stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(int)
stopexpected = stopexpected.sort_values(by=['Scheduled Depart Hour'])
stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(str)


# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Actual Run Time')
plt.plot(stopexpected['Scheduled Depart Hour'], stopexpected['Scheduled Run Time'], label = 'Scheduled Run Time')
  


# # giving a title to my graph
plt.title('2019 Bus Run Time at Stop 2384 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-13-d476b9ddeb64>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-13-d476b9ddeb64>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopexpected['Scheduled Depart Hour'] = stopexpected['Scheduled Depart Hour'].astype(int)
