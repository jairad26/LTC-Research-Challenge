# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import datetime
df = pd.read_csv('data/2020 Line 280 AVL report.csv')
# df = pd.read_csv('data/2019 Line 280 AVL.csv')
df['Actual Depart Hour'] = df['Actual Depart'].str.split(':',expand=True)[0]

bus_dwell_time = df.groupby(['Bus Stop ID','Actual Depart Hour'])['Dwell Time'].sum().reset_index()
# Out:
# C:\Users\Jai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (24) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
stopactual = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 177]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)




# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Dwell Time'], label = 'Dwell Time')
  


# # giving a title to my graph
plt.title('2020 Bus Dwell Time at Stop 177 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-2-024584bd5b9f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)

# %%
stopactual = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 733]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)




# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Dwell Time'], label = 'Dwell Time')
  


# # giving a title to my graph
plt.title('2020 Bus Dwell Time at Stop 733 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-3-ceb5930a8cc1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)

# %%
stopactual = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 738]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)




# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Dwell Time'], label = 'Dwell Time')
  


# # giving a title to my graph
plt.title('2020 Bus Dwell Time at Stop 738 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-4-9cb974a92f3b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)

# %%
stopactual = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 739]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)




# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Dwell Time'], label = 'Dwell Time')
  


# # giving a title to my graph
plt.title('2020 Bus Dwell Time at Stop 739 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-5-8f391521f014>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)

# %%
stopactual = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 741]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)




# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Dwell Time'], label = 'Dwell Time')
  


# # giving a title to my graph
plt.title('2020 Bus Dwell Time at Stop 741 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-6-58112de8dea5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)

# %%
stopactual = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 744]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)




# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Dwell Time'], label = 'Dwell Time')
  


# # giving a title to my graph
plt.title('2020 Bus Dwell Time at Stop 744 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-7-a68729c45313>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)

# %%
stopactual = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 745]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)




# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Dwell Time'], label = 'Dwell Time')
  


# # giving a title to my graph
plt.title('2020 Bus Dwell Time at Stop 745 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-8-15c39b3eac3f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)

# %%
stopactual = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 775]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)




# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Dwell Time'], label = 'Dwell Time')
  


# # giving a title to my graph
plt.title('2020 Bus Dwell Time at Stop 775 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-9-17c16ce98cbe>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)

# %%
stopactual = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 782]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)




# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Dwell Time'], label = 'Dwell Time')
  


# # giving a title to my graph
plt.title('2020 Bus Dwell Time at Stop 782 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-10-6333ad858fc9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)

# %%
stopactual = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 783]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)




# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Dwell Time'], label = 'Dwell Time')
  


# # giving a title to my graph
plt.title('2020 Bus Dwell Time at Stop 783 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-11-3f9488180caf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)

# %%
stopactual = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 2199]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)




# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Dwell Time'], label = 'Dwell Time')
  


# # giving a title to my graph
plt.title('2020 Bus Dwell Time at Stop 2199 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-12-20d44b8a80a7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)

# %%
stopactual = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 2384]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)




# naming the x axis
plt.xlabel('Hours of Day')
# # naming the y axis
plt.ylabel('Minutes')


# #set scale
# plt.xticks([177,738,744,775,782])

  
plt.plot(stopactual['Actual Depart Hour'], stopactual['Dwell Time'], label = 'Dwell Time')
  


# # giving a title to my graph
plt.title('2020 Bus Dwell Time at Stop 2384 Throughout Day')
plt.legend()
# # function to show the plot
plt.show()
# Out:
# <ipython-input-13-7f0a43b4979b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
