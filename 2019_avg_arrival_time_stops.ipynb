# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import datetime
# df = pd.read_csv('data/2020 Line 280 AVL report.csv')
df = pd.read_csv('data/2019 Line 280 AVL.csv')
df['Actual Depart Hour'] = df['Actual Depart'].str.split(':',expand=True)[0]

bus_actual_runtime = df.groupby(['Bus Stop ID','Actual Depart Hour'])['Actual Run Time'].mean().reset_index()
bus_dwell_time = df.groupby(['Bus Stop ID','Actual Depart Hour'])['Dwell Time'].mean().reset_index()
df['Difference (Minutes)'] = df['Difference (Minutes)'].abs()
scheduled_departure_offset = df.groupby(['Bus Stop ID','Actual Depart Hour'])['Difference (Minutes)'].mean().reset_index()

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 177]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)

stopdwell = bus_dwell_time.loc[bus_dwell_time['Bus Stop ID'] == 177]
stopdwell['Actual Depart Hour'] = stopdwell['Actual Depart Hour'].astype(int)
stopdwell = stopdwell.sort_values(by=['Actual Depart Hour'])
stopdwell['Actual Depart Hour'] = stopdwell['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")
ax.set(Title="2019 Bus Run and Dwell Time at Stop 177 Through Hours of the Day", xlabel="Hours of Day", ylabel="Minutes")

plt.plot(stopactual['Actual Depart Hour'], stopdwell['Dwell Time'], label = 'Dwell Time at Stop')
plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Actual Run Time To Stop')

plt.grid()
plt.legend()
plt.show()
# Out:
# <ipython-input-371-7db7a8c13e45>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-371-7db7a8c13e45>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopdwell['Actual Depart Hour'] = stopdwell['Actual Depart Hour'].astype(int)
# <ipython-input-371-7db7a8c13e45>:15: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title="2019 Bus Run and Dwell Time at Stop 177 Through Hours of the Day", xlabel="Hours of Day", ylabel="Minutes")

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 733]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")
ax.set(Title="2019 Bus Run Time at Stop 733 Throughout Day", xlabel="Hours of Day", ylabel="Minutes")


plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Actual Run Time')

plt.grid()
plt.legend()
plt.show()
# Out:
# <ipython-input-372-22a21e0ce75f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-372-22a21e0ce75f>:10: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title="2019 Bus Run Time at Stop 733 Throughout Day", xlabel="Hours of Day", ylabel="Minutes")

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 738]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")
ax.set(Title="2019 Bus Run Time at Stop 738 Throughout Day", xlabel="Hours of Day", ylabel="Minutes")


plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Actual Run Time')

plt.grid()
plt.legend()
plt.show()
# Out:
# <ipython-input-373-81e0cb386288>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-373-81e0cb386288>:10: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title="2019 Bus Run Time at Stop 738 Throughout Day", xlabel="Hours of Day", ylabel="Minutes")

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 739]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")
ax.set(Title="2019 Bus Run Time at Stop 739 Throughout Day", xlabel="Hours of Day", ylabel="Minutes")


plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Average Run Time Offset')

plt.grid()
plt.legend()
plt.show()
# Out:
# <ipython-input-374-993073530af8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-374-993073530af8>:10: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title="2019 Bus Run Time at Stop 739 Throughout Day", xlabel="Hours of Day", ylabel="Minutes")

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 741]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")
ax.set(Title="2019 Bus Run Time at Stop 741 Throughout Day", xlabel="Hours of Day", ylabel="Minutes")


plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Actual Run Time')

plt.grid()
plt.legend()
plt.show()
# Out:
# <ipython-input-375-0c19f80a655b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-375-0c19f80a655b>:10: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title="2019 Bus Run Time at Stop 741 Throughout Day", xlabel="Hours of Day", ylabel="Minutes")

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 744]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")
ax.set(Title="2019 Bus Run Time at Stop 744 Throughout Day", xlabel="Hours of Day", ylabel="Minutes")


plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Actual Run Time')

plt.grid()
plt.legend()
plt.show()
# Out:
# <ipython-input-376-16631a09ac40>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-376-16631a09ac40>:10: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title="2019 Bus Run Time at Stop 744 Throughout Day", xlabel="Hours of Day", ylabel="Minutes")

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 745]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")
ax.set(Title="2019 Bus Run Time at Stop 745 Throughout Day", xlabel="Hours of Day", ylabel="Minutes")


plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Actual Run Time')

plt.grid()
plt.legend()
plt.show()
# Out:
# <ipython-input-377-a9e27b03355a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-377-a9e27b03355a>:10: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title="2019 Bus Run Time at Stop 745 Throughout Day", xlabel="Hours of Day", ylabel="Minutes")

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 775]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")
ax.set(Title="2019 Bus Run Time at Stop 775 Throughout Day", xlabel="Hours of Day", ylabel="Minutes")


plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Actual Run Time')

plt.grid()
plt.legend()
plt.show()
# Out:
# <ipython-input-378-8dcfa29eb291>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-378-8dcfa29eb291>:10: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title="2019 Bus Run Time at Stop 775 Throughout Day", xlabel="Hours of Day", ylabel="Minutes")

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 782]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")
ax.set(Title="2019 Bus Run Time at Stop 782 Throughout Day", xlabel="Hours of Day", ylabel="Minutes")


plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Actual Run Time')

plt.grid()
plt.legend()
plt.show()
# Out:
# <ipython-input-379-c28094253f75>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-379-c28094253f75>:10: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title="2019 Bus Run Time at Stop 782 Throughout Day", xlabel="Hours of Day", ylabel="Minutes")

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 783]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")
ax.set(Title="2019 Bus Run Time at Stop 783 Throughout Day", xlabel="Hours of Day", ylabel="Minutes")


plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Actual Run Time')

plt.grid()
plt.legend()
plt.show()
# Out:
# <ipython-input-380-2331ac23b02a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-380-2331ac23b02a>:10: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title="2019 Bus Run Time at Stop 783 Throughout Day", xlabel="Hours of Day", ylabel="Minutes")

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 2199]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")
ax.set(Title="2019 Bus Run Time at Stop 2199 Throughout Day", xlabel="Hours of Day", ylabel="Minutes")


plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Actual Run Time')

plt.grid()
plt.legend()
plt.show()
# Out:
# <ipython-input-381-a769d975c109>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-381-a769d975c109>:10: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title="2019 Bus Run Time at Stop 2199 Throughout Day", xlabel="Hours of Day", ylabel="Minutes")

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 2384]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")
ax.set(Title="2019 Bus Run Time at Stop 2384 Throughout Day", xlabel="Hours of Day", ylabel="Minutes")


plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Actual Run Time')

plt.grid()
plt.legend()
plt.show()
# Out:
# <ipython-input-382-0555b0f3e7c4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-382-0555b0f3e7c4>:10: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title="2019 Bus Run Time at Stop 2384 Throughout Day", xlabel="Hours of Day", ylabel="Minutes")

# %%
stopactual = bus_actual_runtime.loc[bus_actual_runtime['Bus Stop ID'] == 741]
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
stopactual = stopactual.sort_values(by=['Actual Depart Hour'])
stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(str)



fig, ax = plt.subplots(figsize = (10,4))
plt.plot(kind="line")
ax.set(Title="2019 Bus Run Time at Stop 741 Throughout Day", xlabel="Hours of Day", ylabel="Minutes")


plt.plot(stopactual['Actual Depart Hour'], stopactual['Actual Run Time'], label = 'Actual Run Time')

plt.grid()
plt.legend()
plt.show()
# Out:
# <ipython-input-383-0c19f80a655b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-383-0c19f80a655b>:10: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title="2019 Bus Run Time at Stop 741 Throughout Day", xlabel="Hours of Day", ylabel="Minutes")

# %%
# Out:
# <ipython-input-384-401d85437a03>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stopactual['Actual Depart Hour'] = stopactual['Actual Depart Hour'].astype(int)
# <ipython-input-384-401d85437a03>:9: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title="2019 Bus Departure Time Difference at Stop 741 Throughout Hours of the Day", xlabel="Hours of Day", ylabel="Minutes")
